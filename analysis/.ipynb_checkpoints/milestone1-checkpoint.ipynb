# %%
import pandas as pd
import numpy as np

def load_and_process(path):

    # Method Chain 1 (Load data, rename columns, sort rows by Sport then Year so that we can add win streaks, fix index)

    df1 = (
        pd.read_csv(path)
        .rename(columns={'year':'Year','level':'Level','sport':'Sport','winner':'First Place','winner_metro':'First Place Hometown',
                         'runner_up':'Second Place','runner_up_metro':'Second Place Hometown','final_four3':'Third Place',
                         'final_four3_metro':'Third Place Hometown','final_four4':'Fourth Place','final_four4_metro':'Fourth Place Hometown'}) 
        .sort_values(by=['Sport','Year'])
        .reset_index()
        .drop(columns='index')
        .rename(columns={'level_0':'Index'})
    )
    # Create list of win streaks to add to dataset

    streak = []
    prev = ''
    i = 1
    for team in df1['First Place']:
        if(team == prev):
            i=i+1
        else:
            i=1
        streak.append(i)
        prev = team
    winstreak = pd.Series(streak)

    # Method Chain 2 (add Win Streak column to dataset, capitalize Level column)

    df2 = (
        df1
        .assign(WinStreak=winstreak)
        .rename(columns={'WinStreak':'Win Streak'})
        .assign(Level=df1['Level'].str.capitalize())

    )
    
    return df2
    
load_and_process('../data/raw/dataset.csv')
# Out:
#      Index  Year    Level           Sport               First Place  \
# 0      238  1947  College    Baseball (M)   California Golden Bears
# 1      246  1948  College    Baseball (M)               USC Trojans
# 2      254  1949  College    Baseball (M)           Texas Longhorns
# 3      262  1950  College    Baseball (M)           Texas Longhorns
# 4      270  1951  College    Baseball (M)          Oklahoma Sooners
# ..     ...   ...      ...             ...                       ...
# 991    932  2013  College  Volleyball (W)  Penn State Nittany Lions
# 992    947  2014  College  Volleyball (W)  Penn State Nittany Lions
# 993    960  2015  College  Volleyball (W)      Nebraska Cornhuskers
# 994    971  2016  College  Volleyball (W)         Stanford Cardinal
# 995    984  2017  College  Volleyball (W)      Nebraska Cornhuskers
#
#            First Place Hometown               Second Place  \
# 0    San Francisco Bay Area, CA              Yale Bulldogs
# 1       Greater Los Angeles, CA              Yale Bulldogs
# 2                    Austin, TX  Wake Forest Demon Deacons
# 3                    Austin, TX   Washington State Cougars
# 4             Oklahoma City, OK       Tennessee Volunteers
# ..                          ...                        ...
# 991           State College, PA          Wisconsin Badgers
# 992           State College, PA      Brigham Young Cougars
# 993                 Lincoln, NE            Texas Longhorns
# 994  San Francisco Bay Area, CA            Texas Longhorns
# 995                 Lincoln, NE             Florida Gators
#
#     Second Place Hometown                  Third Place  \
# 0           New Haven, CT  New York University Violets
# 1           New Haven, CT           Lafayette Leopards
# 2       Winston-Salem, NC    Wake Forest Demon Deacons
# 3             Pullman, WA      Rutgers Scarlet Knights
# 4           Knoxville, TN                  USC Trojans
# ..                    ...                          ...
# 991           Madison, WI              Texas Longhorns
# 992             Provo, UT            Stanford Cardinal
# 993            Austin, TX              Kansas Jayhawks
# 994            Austin, TX     Minnesota Golden Gophers
# 995       Gainesville, FL     Penn State Nittany Lions
#
#            Third Place Hometown              Fourth Place  \
# 0           New York Metro Area           Texas Longhorns
# 1          Lehigh Valley, NJ-PA              Baylor Bears
# 2             Winston-Salem, NC               USC Trojans
# 3             New Brunswick, NJ         Wisconsin Badgers
# 4       Greater Los Angeles, CA                 Utah Utes
# ..                          ...                       ...
# 991                  Austin, TX        Washington Huskies
# 992  San Francisco Bay Area, CA           Texas Longhorns
# 993                Lawrence, KS  Minnesota Golden Gophers
# 994             Twin Cities, MN      Nebraska Cornhuskers
# 995           State College, PA         Stanford Cardinal
#
#           Fourth Place Hometown  Win Streak
# 0                    Austin, TX           1
# 1                      Waco, TX           1
# 2       Greater Los Angeles, CA           1
# 3                   Madison, WI           2
# 4            Salt Lake City, UT           1
# ..                          ...         ...
# 991                  Seattle,WA           1
# 992                  Austin, TX           2
# 993             Twin Cities, MN           1
# 994                 Lincoln, NE           1
# 995  San Francisco Bay Area, CA           1
#
# [996 rows x 13 columns]
